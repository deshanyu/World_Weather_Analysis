# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import pprint as pp
import random as rand

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 605

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    city_rain = 0
    city_snow = 0
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        try:
            if "rain" in city_weather_desc:
                city_rain = round(rand.randint(0,10) + rand.random(),2)
            
        except:
            city_rain = 0
        try:
            if "snow" in city_weather_desc:
                city_snow = round(rand.randint(0,10) + rand.random(),2)
        except:
            city_snow = 0
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_weather_desc,
                          "Rain (inches)" : city_rain,
                          "Snow (inches)" : city_snow,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | marsa matruh
# Processing Record 2 of Set 1 | lasem
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | namibe
# Processing Record 5 of Set 1 | kaitangata
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | saint anthony
# Processing Record 8 of Set 1 | batie
# Processing Record 9 of Set 1 | poum
# Processing Record 10 of Set 1 | coquimbo
# Processing Record 11 of Set 1 | chihuahua
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | aklavik
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | sitka
# Processing Record 21 of Set 1 | port blair
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | los llanos de aridane
# Processing Record 25 of Set 1 | rio gallegos
# Processing Record 26 of Set 1 | bambous virieux
# Processing Record 27 of Set 1 | luderitz
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 1 | ko samui
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | mount isa
# Processing Record 33 of Set 1 | snezhnogorsk
# Processing Record 34 of Set 1 | bantou
# Processing Record 35 of Set 1 | shimoda
# Processing Record 36 of Set 1 | koboldo
# City not found. Skipping...
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | hasaki
# Processing Record 39 of Set 1 | saint-georges
# Processing Record 40 of Set 1 | cidreira
# Processing Record 41 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 1 | leningradskiy
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | hamilton
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | upata
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | kavieng
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | dingle
# Processing Record 2 of Set 2 | tawau
# Processing Record 3 of Set 2 | tenenkou
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | hirara
# Processing Record 6 of Set 2 | cherskiy
# Processing Record 7 of Set 2 | naze
# Processing Record 8 of Set 2 | inuvik
# Processing Record 9 of Set 2 | mount gambier
# Processing Record 10 of Set 2 | albertville
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | jujuy
# City not found. Skipping...
# Processing Record 13 of Set 2 | havre-saint-pierre
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | emba
# Processing Record 16 of Set 2 | srednekolymsk
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | yunjinghong
# City not found. Skipping...
# Processing Record 20 of Set 2 | ushuaia
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 2 | alad
# Processing Record 26 of Set 2 | gallup
# Processing Record 27 of Set 2 | birao
# Processing Record 28 of Set 2 | bonthe
# Processing Record 29 of Set 2 | zhoucheng
# Processing Record 30 of Set 2 | jacksonville
# Processing Record 31 of Set 2 | amapa
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | dhidhdhoo
# Processing Record 34 of Set 2 | riyadh
# Processing Record 35 of Set 2 | damghan
# Processing Record 36 of Set 2 | manta
# Processing Record 37 of Set 2 | torbay
# Processing Record 38 of Set 2 | corrente
# Processing Record 39 of Set 2 | kazachinskoye
# Processing Record 40 of Set 2 | tuatapere
# Processing Record 41 of Set 2 | porteirinha
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | dzerzhinsk
# Processing Record 44 of Set 2 | moron
# Processing Record 45 of Set 2 | votice
# Processing Record 46 of Set 2 | fortuna
# Processing Record 47 of Set 2 | cayenne
# Processing Record 48 of Set 2 | rostovka
# Processing Record 49 of Set 2 | iqaluit
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | vardo
# Processing Record 3 of Set 3 | kapuskasing
# Processing Record 4 of Set 3 | kruisfontein
# Processing Record 5 of Set 3 | saskylakh
# Processing Record 6 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 3 | codrington
# Processing Record 8 of Set 3 | nome
# Processing Record 9 of Set 3 | berlevag
# Processing Record 10 of Set 3 | gat
# Processing Record 11 of Set 3 | buala
# Processing Record 12 of Set 3 | souillac
# Processing Record 13 of Set 3 | suntar
# Processing Record 14 of Set 3 | victor harbor
# Processing Record 15 of Set 3 | nishihara
# Processing Record 16 of Set 3 | mount dora
# Processing Record 17 of Set 3 | port-gentil
# Processing Record 18 of Set 3 | monte escobedo
# Processing Record 19 of Set 3 | wanning
# Processing Record 20 of Set 3 | pindobacu
# Processing Record 21 of Set 3 | honiara
# Processing Record 22 of Set 3 | broome
# Processing Record 23 of Set 3 | porto novo
# Processing Record 24 of Set 3 | maniitsoq
# Processing Record 25 of Set 3 | sao joao da barra
# Processing Record 26 of Set 3 | laguna
# Processing Record 27 of Set 3 | mandalgovi
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | mar del plata
# Processing Record 30 of Set 3 | taoudenni
# Processing Record 31 of Set 3 | fairbanks
# Processing Record 32 of Set 3 | faanui
# Processing Record 33 of Set 3 | buchanan
# Processing Record 34 of Set 3 | port hedland
# Processing Record 35 of Set 3 | tilichiki
# Processing Record 36 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 3 | nioro
# Processing Record 38 of Set 3 | dudinka
# Processing Record 39 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 3 | erenhot
# Processing Record 41 of Set 3 | gizo
# Processing Record 42 of Set 3 | ferkessedougou
# Processing Record 43 of Set 3 | redcliffe
# Processing Record 44 of Set 3 | senmonorom
# City not found. Skipping...
# Processing Record 45 of Set 3 | guerrero negro
# Processing Record 46 of Set 3 | tezu
# Processing Record 47 of Set 3 | lorengau
# Processing Record 48 of Set 3 | huambo
# Processing Record 49 of Set 3 | luwuk
# Processing Record 50 of Set 3 | kedrovoye
# Processing Record 1 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 4 | hermanus
# Processing Record 3 of Set 4 | yellowknife
# Processing Record 4 of Set 4 | indian head
# Processing Record 5 of Set 4 | longyearbyen
# Processing Record 6 of Set 4 | ndele
# Processing Record 7 of Set 4 | tuktoyaktuk
# Processing Record 8 of Set 4 | boysun
# Processing Record 9 of Set 4 | tiksi
# Processing Record 10 of Set 4 | braslav
# City not found. Skipping...
# Processing Record 11 of Set 4 | flinders
# Processing Record 12 of Set 4 | port elizabeth
# Processing Record 13 of Set 4 | ketchikan
# Processing Record 14 of Set 4 | okha
# Processing Record 15 of Set 4 | zhangye
# Processing Record 16 of Set 4 | bone
# Processing Record 17 of Set 4 | raudeberg
# Processing Record 18 of Set 4 | severo-yeniseyskiy
# Processing Record 19 of Set 4 | butaritari
# Processing Record 20 of Set 4 | saint george
# Processing Record 21 of Set 4 | bonanza
# Processing Record 22 of Set 4 | sistranda
# Processing Record 23 of Set 4 | husavik
# Processing Record 24 of Set 4 | umm kaddadah
# Processing Record 25 of Set 4 | vastervik
# City not found. Skipping...
# Processing Record 26 of Set 4 | oranjemund
# Processing Record 27 of Set 4 | san quintin
# Processing Record 28 of Set 4 | stettler
# Processing Record 29 of Set 4 | kracheh
# City not found. Skipping...
# Processing Record 30 of Set 4 | norman wells
# Processing Record 31 of Set 4 | rocha
# Processing Record 32 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 4 | altay
# Processing Record 34 of Set 4 | avarua
# Processing Record 35 of Set 4 | morondava
# Processing Record 36 of Set 4 | belmonte
# Processing Record 37 of Set 4 | mwaro
# Processing Record 38 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 4 | pevek
# Processing Record 40 of Set 4 | oistins
# Processing Record 41 of Set 4 | carnarvon
# Processing Record 42 of Set 4 | cabo san lucas
# Processing Record 43 of Set 4 | mitu
# Processing Record 44 of Set 4 | lagoa
# Processing Record 45 of Set 4 | aksu
# Processing Record 46 of Set 4 | huarmey
# Processing Record 47 of Set 4 | galle
# Processing Record 48 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 4 | teguldet
# Processing Record 50 of Set 4 | mnogovershinnyy
# Processing Record 1 of Set 5 | matay
# Processing Record 2 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 5 | thompson
# Processing Record 4 of Set 5 | bairiki
# Processing Record 5 of Set 5 | krasnoselkup
# Processing Record 6 of Set 5 | lebu
# Processing Record 7 of Set 5 | kilindoni
# Processing Record 8 of Set 5 | zarubino
# Processing Record 9 of Set 5 | charters towers
# Processing Record 10 of Set 5 | victoria
# Processing Record 11 of Set 5 | ukiah
# Processing Record 12 of Set 5 | eyl
# Processing Record 13 of Set 5 | beloha
# Processing Record 14 of Set 5 | ponta do sol
# Processing Record 15 of Set 5 | marsabit
# Processing Record 16 of Set 5 | sorong
# Processing Record 17 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 5 | vorokhta
# Processing Record 20 of Set 5 | nanortalik
# Processing Record 21 of Set 5 | karasjok
# Processing Record 22 of Set 5 | vestmannaeyjar
# Processing Record 23 of Set 5 | vestmanna
# Processing Record 24 of Set 5 | kashan
# Processing Record 25 of Set 5 | westminster
# Processing Record 26 of Set 5 | nikolskoye
# Processing Record 27 of Set 5 | padang
# Processing Record 28 of Set 5 | kampil
# Processing Record 29 of Set 5 | saint-michel-des-saints
# Processing Record 30 of Set 5 | mahebourg
# Processing Record 31 of Set 5 | siemiatycze
# Processing Record 32 of Set 5 | milingimbi
# City not found. Skipping...
# Processing Record 33 of Set 5 | kahului
# Processing Record 34 of Set 5 | saint-pierre
# Processing Record 35 of Set 5 | qiqihar
# Processing Record 36 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 37 of Set 5 | awbari
# Processing Record 38 of Set 5 | shchelyayur
# City not found. Skipping...
# Processing Record 39 of Set 5 | esperance
# Processing Record 40 of Set 5 | tekeli
# Processing Record 41 of Set 5 | trairi
# Processing Record 42 of Set 5 | lavrentiya
# Processing Record 43 of Set 5 | hithadhoo
# Processing Record 44 of Set 5 | dunedin
# Processing Record 45 of Set 5 | jos
# Processing Record 46 of Set 5 | stromness
# Processing Record 47 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 5 | clyde river
# Processing Record 50 of Set 5 | chincha alta
# Processing Record 1 of Set 6 | mizdah
# Processing Record 2 of Set 6 | kavaratti
# Processing Record 3 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 4 of Set 6 | salinopolis
# Processing Record 5 of Set 6 | eufaula
# Processing Record 6 of Set 6 | deputatskiy
# Processing Record 7 of Set 6 | ayorou
# Processing Record 8 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 6 | dutlwe
# Processing Record 11 of Set 6 | grindavik
# Processing Record 12 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 6 | imbituba
# Processing Record 14 of Set 6 | provideniya
# Processing Record 15 of Set 6 | tura
# Processing Record 16 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 6 | kropotkin
# Processing Record 18 of Set 6 | nenjiang
# Processing Record 19 of Set 6 | beian
# Processing Record 20 of Set 6 | hobyo
# Processing Record 21 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 22 of Set 6 | kununurra
# Processing Record 23 of Set 6 | hvide sande
# Processing Record 24 of Set 6 | namtsy
# Processing Record 25 of Set 6 | murray bridge
# Processing Record 26 of Set 6 | te anau
# Processing Record 27 of Set 6 | quatre cocos
# Processing Record 28 of Set 6 | coracora
# Processing Record 29 of Set 6 | florence
# Processing Record 30 of Set 6 | ostrovnoy
# Processing Record 31 of Set 6 | alofi
# Processing Record 32 of Set 6 | serebryansk
# Processing Record 33 of Set 6 | kutum
# Processing Record 34 of Set 6 | severo-kurilsk
# Processing Record 35 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 6 | burica
# City not found. Skipping...
# Processing Record 37 of Set 6 | yarmouth
# Processing Record 38 of Set 6 | goderich
# Processing Record 39 of Set 6 | bara
# Processing Record 40 of Set 6 | carutapera
# Processing Record 41 of Set 6 | sobolevo
# Processing Record 42 of Set 6 | upernavik
# Processing Record 43 of Set 6 | lompoc
# Processing Record 44 of Set 6 | mezen
# Processing Record 45 of Set 6 | dzidzantun
# Processing Record 46 of Set 6 | katsuura
# Processing Record 47 of Set 6 | paracatu
# Processing Record 48 of Set 6 | seinajoki
# Processing Record 49 of Set 6 | mehamn
# Processing Record 50 of Set 6 | ahipara
# Processing Record 1 of Set 7 | vostok
# Processing Record 2 of Set 7 | palmer
# Processing Record 3 of Set 7 | college
# Processing Record 4 of Set 7 | jardim
# Processing Record 5 of Set 7 | homer
# Processing Record 6 of Set 7 | hay river
# Processing Record 7 of Set 7 | lyubim
# Processing Record 8 of Set 7 | chipinge
# Processing Record 9 of Set 7 | talnakh
# Processing Record 10 of Set 7 | tonantins
# Processing Record 11 of Set 7 | san policarpo
# Processing Record 12 of Set 7 | blairmore
# Processing Record 13 of Set 7 | mirzapur
# Processing Record 14 of Set 7 | nilai
# Processing Record 15 of Set 7 | nizwa
# Processing Record 16 of Set 7 | newport
# Processing Record 17 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 7 | panjwin
# City not found. Skipping...
# Processing Record 19 of Set 7 | conde
# Processing Record 20 of Set 7 | beringovskiy
# Processing Record 21 of Set 7 | port hardy
# Processing Record 22 of Set 7 | jizan
# Processing Record 23 of Set 7 | katherine
# Processing Record 24 of Set 7 | churachandpur
# Processing Record 25 of Set 7 | roma
# Processing Record 26 of Set 7 | isangel
# Processing Record 27 of Set 7 | sola
# Processing Record 28 of Set 7 | wukari
# Processing Record 29 of Set 7 | santa cruz del sur
# Processing Record 30 of Set 7 | nanakuli
# Processing Record 31 of Set 7 | durazno
# Processing Record 32 of Set 7 | bubaque
# Processing Record 33 of Set 7 | kodiak
# Processing Record 34 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 7 | bilibino
# Processing Record 36 of Set 7 | mahon
# Processing Record 37 of Set 7 | mizan teferi
# Processing Record 38 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 40 of Set 7 | pishin
# Processing Record 41 of Set 7 | bella union
# Processing Record 42 of Set 7 | paamiut
# Processing Record 43 of Set 7 | narsaq
# Processing Record 44 of Set 7 | roald
# Processing Record 45 of Set 7 | tamworth
# Processing Record 46 of Set 7 | valparaiso
# Processing Record 47 of Set 7 | gazojak
# Processing Record 48 of Set 7 | swakopmund
# Processing Record 49 of Set 7 | celestun
# Processing Record 50 of Set 7 | pindiga
# Processing Record 1 of Set 8 | heishan
# Processing Record 2 of Set 8 | coahuayana
# Processing Record 3 of Set 8 | umm bab
# Processing Record 4 of Set 8 | waingapu
# Processing Record 5 of Set 8 | san cristobal
# Processing Record 6 of Set 8 | arlit
# Processing Record 7 of Set 8 | rafai
# Processing Record 8 of Set 8 | westport
# Processing Record 9 of Set 8 | karratha
# Processing Record 10 of Set 8 | pedro juan caballero
# Processing Record 11 of Set 8 | puerto del rosario
# Processing Record 12 of Set 8 | ilulissat
# Processing Record 13 of Set 8 | iwanai
# Processing Record 14 of Set 8 | pangoa
# Processing Record 15 of Set 8 | fort-shevchenko
# Processing Record 16 of Set 8 | taybad
# Processing Record 17 of Set 8 | baker city
# Processing Record 18 of Set 8 | yulara
# Processing Record 19 of Set 8 | anamur
# Processing Record 20 of Set 8 | morehead
# Processing Record 21 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 22 of Set 8 | bria
# Processing Record 23 of Set 8 | paragominas
# Processing Record 24 of Set 8 | salto
# Processing Record 25 of Set 8 | jiancheng
# Processing Record 26 of Set 8 | nara
# Processing Record 27 of Set 8 | bud
# Processing Record 28 of Set 8 | sakakah
# Processing Record 29 of Set 8 | makakilo city
# Processing Record 30 of Set 8 | anchorage
# Processing Record 31 of Set 8 | zatyshshya
# Processing Record 32 of Set 8 | mantua
# Processing Record 33 of Set 8 | asau
# Processing Record 34 of Set 8 | presidencia roque saenz pena
# Processing Record 35 of Set 8 | ancud
# Processing Record 36 of Set 8 | qarchi gak
# Processing Record 37 of Set 8 | airai
# Processing Record 38 of Set 8 | fukue
# Processing Record 39 of Set 8 | channel-port aux basques
# Processing Record 40 of Set 8 | lumut
# Processing Record 41 of Set 8 | hauterive
# Processing Record 42 of Set 8 | coolum beach
# Processing Record 43 of Set 8 | nhulunbuy
# Processing Record 44 of Set 8 | soyo
# Processing Record 45 of Set 8 | bratsk
# Processing Record 46 of Set 8 | khandyga
# Processing Record 47 of Set 8 | henties bay
# Processing Record 48 of Set 8 | shahr-e kord
# Processing Record 49 of Set 8 | la ronge
# Processing Record 50 of Set 8 | tjome
# Processing Record 1 of Set 9 | yeppoon
# Processing Record 2 of Set 9 | bengkulu
# Processing Record 3 of Set 9 | soligalich
# Processing Record 4 of Set 9 | bakchar
# Processing Record 5 of Set 9 | dogondoutchi
# Processing Record 6 of Set 9 | bathsheba
# Processing Record 7 of Set 9 | hofn
# Processing Record 8 of Set 9 | juneau
# Processing Record 9 of Set 9 | gandajika
# Processing Record 10 of Set 9 | san carlos de bariloche
# Processing Record 11 of Set 9 | otofuke
# Processing Record 12 of Set 9 | key west
# Processing Record 13 of Set 9 | bar harbor
# Processing Record 14 of Set 9 | biak
# Processing Record 15 of Set 9 | payo
# Processing Record 16 of Set 9 | kupang
# Processing Record 17 of Set 9 | launceston
# Processing Record 18 of Set 9 | sibolga
# Processing Record 19 of Set 9 | cairns
# Processing Record 20 of Set 9 | melong
# Processing Record 21 of Set 9 | walvis bay
# Processing Record 22 of Set 9 | xiongzhou
# Processing Record 23 of Set 9 | san miguel
# Processing Record 24 of Set 9 | svirstroy
# Processing Record 25 of Set 9 | lasa
# Processing Record 26 of Set 9 | kukushtan
# Processing Record 27 of Set 9 | kita
# Processing Record 28 of Set 9 | hami
# Processing Record 29 of Set 9 | yakeshi
# Processing Record 30 of Set 9 | ixtapa
# Processing Record 31 of Set 9 | mandurah
# Processing Record 32 of Set 9 | saint-francois
# Processing Record 33 of Set 9 | sovetskiy
# Processing Record 34 of Set 9 | sao filipe
# Processing Record 35 of Set 9 | pucallpa
# Processing Record 36 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 9 | shingu
# Processing Record 38 of Set 9 | mecca
# Processing Record 39 of Set 9 | matagami
# Processing Record 40 of Set 9 | klaksvik
# Processing Record 41 of Set 9 | portland
# Processing Record 42 of Set 9 | comodoro rivadavia
# Processing Record 43 of Set 9 | palana
# Processing Record 44 of Set 9 | santa branca
# Processing Record 45 of Set 9 | prince rupert
# Processing Record 46 of Set 9 | yerbogachen
# Processing Record 47 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 48 of Set 9 | margate
# Processing Record 49 of Set 9 | abhar
# Processing Record 50 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 10 | xichang
# Processing Record 2 of Set 10 | komsomolskiy
# Processing Record 3 of Set 10 | humberto de campos
# Processing Record 4 of Set 10 | zgierz
# Processing Record 5 of Set 10 | tornio
# Processing Record 6 of Set 10 | topolobampo
# Processing Record 7 of Set 10 | anadyr
# Processing Record 8 of Set 10 | guadalajara
# Processing Record 9 of Set 10 | gondar
# Processing Record 10 of Set 10 | meulaboh
# Processing Record 11 of Set 10 | kayes
# Processing Record 12 of Set 10 | moa
# Processing Record 13 of Set 10 | udachnyy
# Processing Record 14 of Set 10 | satipo
# Processing Record 15 of Set 10 | nemuro
# Processing Record 16 of Set 10 | beba
# Processing Record 17 of Set 10 | altamira
# Processing Record 18 of Set 10 | chunskiy
# Processing Record 19 of Set 10 | manzanillo
# Processing Record 20 of Set 10 | solnechnyy
# Processing Record 21 of Set 10 | balkanabat
# Processing Record 22 of Set 10 | cumberland
# Processing Record 23 of Set 10 | bogovarovo
# Processing Record 24 of Set 10 | vammala
# Processing Record 25 of Set 10 | pisco
# Processing Record 26 of Set 10 | rawson
# Processing Record 27 of Set 10 | turka
# Processing Record 28 of Set 10 | nelson bay
# Processing Record 29 of Set 10 | arcata
# Processing Record 30 of Set 10 | lecce
# Processing Record 31 of Set 10 | sabang
# Processing Record 32 of Set 10 | churapcha
# Processing Record 33 of Set 10 | okato
# Processing Record 34 of Set 10 | vao
# Processing Record 35 of Set 10 | ulaangom
# Processing Record 36 of Set 10 | pingdingshan
# Processing Record 37 of Set 10 | jieshou
# Processing Record 38 of Set 10 | kamenka
# Processing Record 39 of Set 10 | nantucket
# Processing Record 40 of Set 10 | trifesti
# Processing Record 41 of Set 10 | sinnamary
# Processing Record 42 of Set 10 | rio grande
# Processing Record 43 of Set 10 | barpeta
# Processing Record 44 of Set 10 | tucano
# Processing Record 45 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 46 of Set 10 | brae
# Processing Record 47 of Set 10 | zhuhai
# Processing Record 48 of Set 10 | tripoli
# Processing Record 49 of Set 10 | tifton
# Processing Record 50 of Set 10 | ustupo
# Processing Record 1 of Set 11 | hailun
# Processing Record 2 of Set 11 | muros
# Processing Record 3 of Set 11 | williams lake
# Processing Record 4 of Set 11 | marawi
# Processing Record 5 of Set 11 | buenos aires
# Processing Record 6 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 7 of Set 11 | ulladulla
# Processing Record 8 of Set 11 | olafsvik
# Processing Record 9 of Set 11 | krutikha
# Processing Record 10 of Set 11 | coihaique
# Processing Record 11 of Set 11 | mogadishu
# Processing Record 12 of Set 11 | lazaro cardenas
# Processing Record 13 of Set 11 | markova
# Processing Record 14 of Set 11 | diapaga
# Processing Record 15 of Set 11 | puerto el triunfo
# Processing Record 16 of Set 11 | santa cruz
# Processing Record 17 of Set 11 | uchiza
# Processing Record 18 of Set 11 | colares
# Processing Record 19 of Set 11 | kendari
# Processing Record 20 of Set 11 | dwarka
# Processing Record 21 of Set 11 | half moon bay
# Processing Record 22 of Set 11 | zhicheng
# Processing Record 23 of Set 11 | lianran
# Processing Record 24 of Set 11 | ouadda
# Processing Record 25 of Set 11 | ambon
# Processing Record 26 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 27 of Set 11 | waitara
# Processing Record 28 of Set 11 | turayf
# Processing Record 29 of Set 11 | saldanha
# Processing Record 30 of Set 11 | natal
# Processing Record 31 of Set 11 | chornoliztsi
# Processing Record 32 of Set 11 | kafue
# Processing Record 33 of Set 11 | biu
# Processing Record 34 of Set 11 | mikhaylovsk
# Processing Record 35 of Set 11 | kamaishi
# Processing Record 36 of Set 11 | vakhrushev
# Processing Record 37 of Set 11 | irbit
# Processing Record 38 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 39 of Set 11 | yaan
# Processing Record 40 of Set 11 | sharanga
# Processing Record 41 of Set 11 | pasighat
# Processing Record 42 of Set 11 | nabinagar
# Processing Record 43 of Set 11 | ormara
# Processing Record 44 of Set 11 | baruun-urt
# Processing Record 45 of Set 11 | naantali
# Processing Record 46 of Set 11 | atasu
# Processing Record 47 of Set 11 | allende
# Processing Record 48 of Set 11 | almaznyy
# Processing Record 49 of Set 11 | caravelas
# Processing Record 50 of Set 11 | amalapuram
# Processing Record 1 of Set 12 | morbegno
# Processing Record 2 of Set 12 | gobabis
# Processing Record 3 of Set 12 | xuanhua
# Processing Record 4 of Set 12 | abnub
# Processing Record 5 of Set 12 | chinsali
# Processing Record 6 of Set 12 | babanka
# Processing Record 7 of Set 12 | sampit
# Processing Record 8 of Set 12 | ilo
# Processing Record 9 of Set 12 | adre
# Processing Record 10 of Set 12 | antonina
# Processing Record 11 of Set 12 | kloulklubed
# Processing Record 12 of Set 12 | verkhnyaya inta
# Processing Record 13 of Set 12 | callander
# Processing Record 14 of Set 12 | lephepe
# City not found. Skipping...
# Processing Record 15 of Set 12 | cap malheureux
# Processing Record 16 of Set 12 | madina
# Processing Record 17 of Set 12 | broken hill
# Processing Record 18 of Set 12 | nakusp
# Processing Record 19 of Set 12 | illapel
# Processing Record 20 of Set 12 | adrar
# Processing Record 21 of Set 12 | liwale
# Processing Record 22 of Set 12 | nicoya
# Processing Record 23 of Set 12 | turukhansk
# Processing Record 24 of Set 12 | bowen
# Processing Record 25 of Set 12 | the pas
# Processing Record 26 of Set 12 | pangnirtung
# Processing Record 27 of Set 12 | ilhabela
# Processing Record 28 of Set 12 | sona
# Processing Record 29 of Set 12 | sayyan
# Processing Record 30 of Set 12 | tabarqah
# City not found. Skipping...
# Processing Record 31 of Set 12 | kaoma
# Processing Record 32 of Set 12 | rapid valley
# Processing Record 33 of Set 12 | porto belo
# Processing Record 34 of Set 12 | havre
# Processing Record 35 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 36 of Set 12 | cascais
# Processing Record 37 of Set 12 | likasi
# Processing Record 38 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 12 | zhigansk
# Processing Record 40 of Set 12 | champerico
# Processing Record 41 of Set 12 | constitucion
# Processing Record 42 of Set 12 | corn island
# Processing Record 43 of Set 12 | manati
# Processing Record 44 of Set 12 | matsanga
# City not found. Skipping...
# Processing Record 45 of Set 12 | ondangwa
# Processing Record 46 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 12 | high prairie
# Processing Record 48 of Set 12 | zacualtipan
# Processing Record 49 of Set 12 | yarada
# Processing Record 50 of Set 12 | sorland
# Processing Record 1 of Set 13 | namatanai
# Processing Record 2 of Set 13 | kalevala
# Processing Record 3 of Set 13 | kaeo
# Processing Record 4 of Set 13 | kaunas
# Processing Record 5 of Set 13 | wellington
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
pp.pprint(city_weather)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 35},
#  'cod': 200,
#  'coord': {'lat': -41.29, 'lon': 174.78},
#  'dt': 1592773804,
#  'id': 2179537,
#  'main': {'feels_like': 45.01,
#           'humidity': 93,
#           'pressure': 1024,
#           'temp': 48.97,
#           'temp_max': 50,
#           'temp_min': 48},
#  'name': 'Wellington',
#  'sys': {'country': 'NZ',
#          'id': 7358,
#          'sunrise': 1592768828,
#          'sunset': 1592801909,
#          'type': 1},
#  'timezone': 43200,
#  'visibility': 7000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 200, 'speed': 5.82}}

# %%
weather_data = pd.DataFrame(city_data)

new_columns = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description','Rain (inches)','Snow (inches)']
weather_data = weather_data[new_columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
weather_data.to_csv(output_data_file, index_label="City_ID")

# %%
foo[foo['Current Description'] == "thunderstorm with rain"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d016edc73434> in <module>
# ----> 1 foo[foo['Current Description'] == "thunderstorm with rain"]
#
# NameError: name 'foo' is not defined
